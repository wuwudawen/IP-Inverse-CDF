# %%
import jax
import jax.numpy as jnp
from jax import jit, vmap, grad
from jax import random
import optax
import numpy as np
import pickle

# %%
def init_network_params(sizes, key=random.PRNGKey(4)):
    def random_layer_params(m, n, key, scale=1e-2):
        w_key, b_key = random.split(key)
        return scale * random.uniform(w_key, (n, m), minval=1, maxval=3), scale * random.uniform(b_key, (n,), minval=1, maxval=3)

    keys = random.split(key, len(sizes))
    return [random_layer_params(m, n, k) for m, n, k in zip(sizes[:-1], sizes[1:], keys)]

def predict(NN, u):
    activations = u.reshape((-1, ))
    activations = jnp.log(activations/(1-activations))
    for w, b in NN[:-1]:
        outputs = jnp.dot(w, activations) + b
        activations = jax.nn.sigmoid(outputs)
    final_w, final_b = NN[-1]
    logit = jnp.dot(final_w, activations) + final_b
    return logit.squeeze()

vpredict = vmap(predict, in_axes=(None, 0))
gpredict = grad(predict, argnums=1)
vgpredict = jit(vmap(gpredict, in_axes=(None, 0)))

# %%
def pi(x):
    result = jnp.exp(-x**4)
    result = result/1.812804958472487
    # result = jnp.where((x >= 0) & (x <= 2), result, 0)
    result = jnp.where(result==0, 1e-10, result)
    return result
vpi = vmap(pi, in_axes=(0,))

@jit
def obj(NN, u_batch):
    def ell(NN, u):
        return -jnp.log(pi(predict(NN, u))) - jnp.log(gpredict(NN, u))
    vell = vmap(ell, in_axes=(None, 0))

    result = vell(NN, u_batch)
    result = jnp.mean(result)
    return result

@jit
def constraint(NN, u_batch):
    epsilon = 1e-12
    def g(NN, u):
        return jnp.maximum(-gpredict(NN, u)+epsilon, 0)
    vg = vmap(g, in_axes=(None, 0))

    result = vg(NN, u_batch)
    result = jnp.sum(result)
    return result

gobj = jit(grad(obj))
gconst = jit(grad(constraint))

@jit
def evaluation(NN, test_uz):
    u_batch, z_batch = test_uz[:, 0], test_uz[:, 1]
    result = jnp.square(vpredict(NN, u_batch) - z_batch)
    result = jnp.mean(result)
    return result

# %%
LAYER_SIZES = [1, 10, 10, 10, 1]
NN = init_network_params(LAYER_SIZES, random.PRNGKey(15))

optimizer= optax.adam(0.001)
opt_state = optimizer.init(NN)
bug = 0
co = 0
test_uz = np.load(f'/content/drive/MyDrive/No. 22 Physica D (inverse)/Abstract checkpoints (TM)/test_uz.npy')
lowest = evaluation(NN, test_uz)
Lloss = []
Llowest = []
NN_best = NN
for epoch in range(2000000):
    u_batch = np.random.uniform(0, 1, (10000, 1))
    while jnp.isnan(vgpredict(NN, u_batch)).sum() != 0:
        u_batch = np.random.uniform(0, 1, (10000, 1))
        bug += 1

    while constraint(NN, u_batch).item()>0:
        grads = gconst(NN, u_batch)
        updates, opt_state = optimizer.update(grads, opt_state)
        NN = optax.apply_updates(NN, updates)
        co += 1

    grads = gobj(NN, u_batch)
    updates, opt_state = optimizer.update(grads, opt_state)
    NN = optax.apply_updates(NN, updates)

    Lloss.append(obj(NN, u_batch).item())
    Llowest.append(lowest.item())

    if  evaluation(NN, test_uz)<lowest:
        lowest = evaluation(NN, test_uz)
        NN_best = NN

    if epoch % 10000 == 0:
        print(f"Epoch: {epoch}, loss:{obj(NN, u_batch).item():.7f}, const:{constraint(NN, u_batch).item():.4f}, lowest:{lowest:.4f}, co:{co}, bug:{bug}")
        np.save(f'/content/drive/MyDrive/No. 22 Physica D (inverse)/Abstract checkpoints (TM)/Lloss.npy', Lloss)
        np.save(f'/content/drive/MyDrive/No. 22 Physica D (inverse)/Abstract checkpoints (TM)/Llowest.npy', Llowest)
        with open(f'/content/drive/MyDrive/No. 22 Physica D (inverse)/Abstract checkpoints (TM)/NN (best).pkl', 'wb') as f:
            pickle.dump(NN_best, f)
        with open(f'/content/drive/MyDrive/No. 22 Physica D (inverse)/Abstract checkpoints (TM)/NN_{epoch}.pkl', 'wb') as f:
            pickle.dump(NN, f)
# Out:
# Epoch: 0, loss:11.1941175, const:0.0000, lowest:0.6663, co:0, bug:0
# Epoch: 10000, loss:0.0008336, const:0.0000, lowest:0.0000, co:0, bug:2
# Epoch: 20000, loss:0.0001326, const:0.0000, lowest:0.0000, co:0, bug:8
# Epoch: 30000, loss:0.0000140, const:0.0000, lowest:0.0000, co:0, bug:8
# Epoch: 40000, loss:0.0000894, const:0.0000, lowest:0.0000, co:0, bug:11
# Epoch: 50000, loss:0.0000003, const:0.0000, lowest:0.0000, co:0, bug:14
# Epoch: 60000, loss:-0.0000915, const:0.0000, lowest:0.0000, co:0, bug:16
# Epoch: 70000, loss:0.0000501, const:0.0000, lowest:0.0000, co:0, bug:18
# Epoch: 80000, loss:-0.0000890, const:0.0000, lowest:0.0000, co:0, bug:21
# Epoch: 90000, loss:-0.0000284, const:0.0000, lowest:0.0000, co:0, bug:24
# Epoch: 100000, loss:0.0006535, const:0.0000, lowest:0.0000, co:0, bug:26
# Epoch: 110000, loss:0.0000562, const:0.0000, lowest:0.0000, co:0, bug:28
# Epoch: 120000, loss:0.0000099, const:0.0000, lowest:0.0000, co:0, bug:31
# Epoch: 130000, loss:0.0000713, const:0.0000, lowest:0.0000, co:0, bug:35
# Epoch: 140000, loss:0.0000901, const:0.0000, lowest:0.0000, co:0, bug:39
# Epoch: 150000, loss:0.0000511, const:0.0000, lowest:0.0000, co:0, bug:42
# Epoch: 160000, loss:-0.0000200, const:0.0000, lowest:0.0000, co:0, bug:44
# Epoch: 170000, loss:-0.0000083, const:0.0000, lowest:0.0000, co:0, bug:49
# Epoch: 180000, loss:0.0000331, const:0.0000, lowest:0.0000, co:0, bug:53
# Epoch: 190000, loss:0.0001930, const:0.0000, lowest:0.0000, co:0, bug:53
# Epoch: 200000, loss:-0.0000445, const:0.0000, lowest:0.0000, co:0, bug:56
# Epoch: 210000, loss:0.0000104, const:0.0000, lowest:0.0000, co:0, bug:59
# Epoch: 220000, loss:0.0000349, const:0.0000, lowest:0.0000, co:0, bug:62
# Epoch: 230000, loss:0.0002302, const:0.0000, lowest:0.0000, co:0, bug:63
# Epoch: 240000, loss:-0.0002570, const:0.0000, lowest:0.0000, co:0, bug:66
# Epoch: 250000, loss:0.0001110, const:0.0000, lowest:0.0000, co:0, bug:69
# Epoch: 260000, loss:-0.0001458, const:0.0000, lowest:0.0000, co:0, bug:72
# Epoch: 270000, loss:0.0002265, const:0.0000, lowest:0.0000, co:0, bug:77
# Epoch: 280000, loss:-0.0000590, const:0.0000, lowest:0.0000, co:0, bug:82
# Epoch: 290000, loss:-0.0000227, const:0.0000, lowest:0.0000, co:0, bug:87
# Epoch: 300000, loss:-0.0001538, const:0.0000, lowest:0.0000, co:0, bug:90
# Epoch: 310000, loss:0.0001831, const:0.0000, lowest:0.0000, co:0, bug:92
# Epoch: 320000, loss:-0.0001038, const:0.0000, lowest:0.0000, co:0, bug:94
# Epoch: 330000, loss:0.0001263, const:0.0000, lowest:0.0000, co:0, bug:97
# Epoch: 340000, loss:0.0000399, const:0.0000, lowest:0.0000, co:0, bug:97
# Epoch: 350000, loss:0.0002647, const:0.0000, lowest:0.0000, co:0, bug:102
# Epoch: 360000, loss:0.0000462, const:0.0000, lowest:0.0000, co:0, bug:104
# Epoch: 370000, loss:0.0003870, const:0.0000, lowest:0.0000, co:0, bug:106
# Epoch: 380000, loss:-0.0000107, const:0.0000, lowest:0.0000, co:0, bug:109
# Epoch: 390000, loss:-0.0000983, const:0.0000, lowest:0.0000, co:0, bug:111
# Epoch: 400000, loss:0.0001424, const:0.0000, lowest:0.0000, co:0, bug:116
# Epoch: 410000, loss:0.0001936, const:0.0000, lowest:0.0000, co:0, bug:118
# Epoch: 420000, loss:0.0001196, const:0.0000, lowest:0.0000, co:0, bug:123
# Epoch: 430000, loss:-0.0000154, const:0.0000, lowest:0.0000, co:0, bug:125
# Epoch: 440000, loss:0.0000293, const:0.0000, lowest:0.0000, co:0, bug:128
# Epoch: 450000, loss:0.0000507, const:0.0000, lowest:0.0000, co:0, bug:135
# Epoch: 460000, loss:0.0000831, const:0.0000, lowest:0.0000, co:0, bug:141
# Epoch: 470000, loss:-0.0000626, const:0.0000, lowest:0.0000, co:0, bug:145
# Epoch: 480000, loss:0.0000024, const:0.0000, lowest:0.0000, co:0, bug:147
# Epoch: 490000, loss:0.0002146, const:0.0000, lowest:0.0000, co:0, bug:150
# Epoch: 500000, loss:0.0003275, const:0.0000, lowest:0.0000, co:0, bug:151
# Epoch: 510000, loss:0.0000438, const:0.0000, lowest:0.0000, co:0, bug:153
# Epoch: 520000, loss:-0.0000067, const:0.0000, lowest:0.0000, co:0, bug:157
# Epoch: 530000, loss:0.0000421, const:0.0000, lowest:0.0000, co:0, bug:159
# Epoch: 540000, loss:0.0001028, const:0.0000, lowest:0.0000, co:0, bug:160
# Epoch: 550000, loss:0.0004786, const:0.0000, lowest:0.0000, co:0, bug:161
# Epoch: 560000, loss:-0.0002389, const:0.0000, lowest:0.0000, co:0, bug:166
# Epoch: 570000, loss:-0.0000453, const:0.0000, lowest:0.0000, co:0, bug:170
# Epoch: 580000, loss:0.0001082, const:0.0000, lowest:0.0000, co:0, bug:174
# Epoch: 590000, loss:-0.0001023, const:0.0000, lowest:0.0000, co:0, bug:180
# Epoch: 600000, loss:0.0000043, const:0.0000, lowest:0.0000, co:0, bug:181
# Epoch: 610000, loss:0.0002659, const:0.0000, lowest:0.0000, co:0, bug:182
# Epoch: 620000, loss:-0.0000929, const:0.0000, lowest:0.0000, co:0, bug:185
# Epoch: 630000, loss:0.0003542, const:0.0000, lowest:0.0000, co:0, bug:189
# Epoch: 640000, loss:-0.0000683, const:0.0000, lowest:0.0000, co:0, bug:197
# Epoch: 650000, loss:0.0001018, const:0.0000, lowest:0.0000, co:0, bug:198
# Epoch: 660000, loss:0.0001038, const:0.0000, lowest:0.0000, co:0, bug:201
# Epoch: 670000, loss:0.0001271, const:0.0000, lowest:0.0000, co:0, bug:208
# Epoch: 680000, loss:0.0000342, const:0.0000, lowest:0.0000, co:0, bug:213
# Epoch: 690000, loss:0.0001079, const:0.0000, lowest:0.0000, co:0, bug:215
# Epoch: 700000, loss:0.0000393, const:0.0000, lowest:0.0000, co:0, bug:216
# Epoch: 710000, loss:0.0000896, const:0.0000, lowest:0.0000, co:0, bug:219
# Epoch: 720000, loss:-0.0000128, const:0.0000, lowest:0.0000, co:0, bug:220
# Epoch: 730000, loss:-0.0001297, const:0.0000, lowest:0.0000, co:0, bug:222
# Epoch: 740000, loss:0.0000941, const:0.0000, lowest:0.0000, co:0, bug:224
# Epoch: 750000, loss:0.0002377, const:0.0000, lowest:0.0000, co:0, bug:227
# Epoch: 760000, loss:-0.0001604, const:0.0000, lowest:0.0000, co:0, bug:234
# Epoch: 770000, loss:0.0003685, const:0.0000, lowest:0.0000, co:0, bug:237
# Epoch: 780000, loss:0.0000372, const:0.0000, lowest:0.0000, co:0, bug:239
# Epoch: 790000, loss:0.0000186, const:0.0000, lowest:0.0000, co:0, bug:245
# Epoch: 800000, loss:-0.0000522, const:0.0000, lowest:0.0000, co:0, bug:249
# Epoch: 810000, loss:0.0001768, const:0.0000, lowest:0.0000, co:0, bug:249
# Epoch: 820000, loss:0.0002882, const:0.0000, lowest:0.0000, co:0, bug:251
# Epoch: 830000, loss:-0.0000867, const:0.0000, lowest:0.0000, co:0, bug:251
# Epoch: 840000, loss:0.0000748, const:0.0000, lowest:0.0000, co:0, bug:253
# Epoch: 850000, loss:0.0002053, const:0.0000, lowest:0.0000, co:0, bug:256
# Epoch: 860000, loss:0.0001580, const:0.0000, lowest:0.0000, co:0, bug:260
# Epoch: 870000, loss:0.0000267, const:0.0000, lowest:0.0000, co:0, bug:262
# Epoch: 880000, loss:0.0000299, const:0.0000, lowest:0.0000, co:0, bug:264
# Epoch: 890000, loss:0.0000193, const:0.0000, lowest:0.0000, co:0, bug:265
# Epoch: 900000, loss:-0.0000355, const:0.0000, lowest:0.0000, co:0, bug:269
# Epoch: 910000, loss:-0.0000455, const:0.0000, lowest:0.0000, co:0, bug:274
# Epoch: 920000, loss:-0.0000720, const:0.0000, lowest:0.0000, co:0, bug:276
# Epoch: 930000, loss:0.0001218, const:0.0000, lowest:0.0000, co:0, bug:281
# Epoch: 940000, loss:0.0000147, const:0.0000, lowest:0.0000, co:0, bug:283
# Epoch: 950000, loss:-0.0000625, const:0.0000, lowest:0.0000, co:0, bug:287
# Epoch: 960000, loss:-0.0000078, const:0.0000, lowest:0.0000, co:0, bug:292
# Epoch: 970000, loss:-0.0000018, const:0.0000, lowest:0.0000, co:0, bug:293
# Epoch: 980000, loss:-0.0000349, const:0.0000, lowest:0.0000, co:0, bug:294
# Epoch: 990000, loss:0.0000286, const:0.0000, lowest:0.0000, co:0, bug:295
# Epoch: 1000000, loss:0.0001042, const:0.0000, lowest:0.0000, co:0, bug:298
# Epoch: 1010000, loss:-0.0000982, const:0.0000, lowest:0.0000, co:0, bug:298
# Epoch: 1020000, loss:0.0000105, const:0.0000, lowest:0.0000, co:0, bug:303
# Epoch: 1030000, loss:-0.0001013, const:0.0000, lowest:0.0000, co:0, bug:307
# Epoch: 1040000, loss:0.0001968, const:0.0000, lowest:0.0000, co:0, bug:308
# Epoch: 1050000, loss:0.0001004, const:0.0000, lowest:0.0000, co:0, bug:310
# Epoch: 1060000, loss:-0.0002428, const:0.0000, lowest:0.0000, co:0, bug:312
# Epoch: 1070000, loss:0.0000433, const:0.0000, lowest:0.0000, co:0, bug:319
# Epoch: 1080000, loss:0.0000280, const:0.0000, lowest:0.0000, co:0, bug:321
# Epoch: 1090000, loss:0.0000661, const:0.0000, lowest:0.0000, co:0, bug:323
# Epoch: 1100000, loss:0.0000277, const:0.0000, lowest:0.0000, co:0, bug:326
# Epoch: 1110000, loss:-0.0000483, const:0.0000, lowest:0.0000, co:0, bug:327
# Epoch: 1120000, loss:-0.0000073, const:0.0000, lowest:0.0000, co:0, bug:331
# Epoch: 1130000, loss:0.0000390, const:0.0000, lowest:0.0000, co:0, bug:332
# Epoch: 1140000, loss:0.0002948, const:0.0000, lowest:0.0000, co:0, bug:333
# Epoch: 1150000, loss:-0.0001859, const:0.0000, lowest:0.0000, co:0, bug:335
# Epoch: 1160000, loss:0.0000354, const:0.0000, lowest:0.0000, co:0, bug:337
# Epoch: 1170000, loss:0.0000367, const:0.0000, lowest:0.0000, co:0, bug:339
# Epoch: 1180000, loss:0.0003740, const:0.0000, lowest:0.0000, co:0, bug:341
# Epoch: 1190000, loss:0.0003160, const:0.0000, lowest:0.0000, co:0, bug:341
# Epoch: 1200000, loss:-0.0000720, const:0.0000, lowest:0.0000, co:0, bug:346
# Epoch: 1210000, loss:0.0000367, const:0.0000, lowest:0.0000, co:0, bug:347
# Epoch: 1220000, loss:-0.0000269, const:0.0000, lowest:0.0000, co:0, bug:348
# Epoch: 1230000, loss:0.0005581, const:0.0000, lowest:0.0000, co:0, bug:354
# Epoch: 1240000, loss:0.0001116, const:0.0000, lowest:0.0000, co:0, bug:357
# Epoch: 1250000, loss:-0.0000204, const:0.0000, lowest:0.0000, co:0, bug:362
# Epoch: 1260000, loss:0.0000501, const:0.0000, lowest:0.0000, co:0, bug:366
# Epoch: 1270000, loss:-0.0000712, const:0.0000, lowest:0.0000, co:0, bug:367
# Epoch: 1280000, loss:-0.0000083, const:0.0000, lowest:0.0000, co:0, bug:370
# Epoch: 1290000, loss:0.0000345, const:0.0000, lowest:0.0000, co:0, bug:372
# Epoch: 1300000, loss:-0.0000927, const:0.0000, lowest:0.0000, co:0, bug:379
# Epoch: 1310000, loss:-0.0000113, const:0.0000, lowest:0.0000, co:0, bug:385
# Epoch: 1320000, loss:0.0000491, const:0.0000, lowest:0.0000, co:0, bug:391
# Epoch: 1330000, loss:-0.0000015, const:0.0000, lowest:0.0000, co:0, bug:393
# Epoch: 1340000, loss:-0.0000429, const:0.0000, lowest:0.0000, co:0, bug:396
# Epoch: 1350000, loss:-0.0000846, const:0.0000, lowest:0.0000, co:0, bug:398
# Epoch: 1360000, loss:0.0000358, const:0.0000, lowest:0.0000, co:0, bug:400
# Epoch: 1370000, loss:0.0000922, const:0.0000, lowest:0.0000, co:0, bug:403
# Epoch: 1380000, loss:0.0001243, const:0.0000, lowest:0.0000, co:0, bug:405
# Epoch: 1390000, loss:0.0000307, const:0.0000, lowest:0.0000, co:0, bug:409
# Epoch: 1400000, loss:-0.0000066, const:0.0000, lowest:0.0000, co:0, bug:413
# Epoch: 1410000, loss:0.0000551, const:0.0000, lowest:0.0000, co:0, bug:415
# Epoch: 1420000, loss:0.0000551, const:0.0000, lowest:0.0000, co:0, bug:419
# Epoch: 1430000, loss:0.0000942, const:0.0000, lowest:0.0000, co:0, bug:419
# Epoch: 1440000, loss:0.0000621, const:0.0000, lowest:0.0000, co:0, bug:422
# Epoch: 1450000, loss:0.0001085, const:0.0000, lowest:0.0000, co:0, bug:428
# Epoch: 1460000, loss:0.0003847, const:0.0000, lowest:0.0000, co:0, bug:429
# Epoch: 1470000, loss:0.0000212, const:0.0000, lowest:0.0000, co:0, bug:435
# Epoch: 1480000, loss:0.0001917, const:0.0000, lowest:0.0000, co:0, bug:438
# Epoch: 1490000, loss:0.0002103, const:0.0000, lowest:0.0000, co:0, bug:441
# Epoch: 1500000, loss:0.0001015, const:0.0000, lowest:0.0000, co:0, bug:447
# Epoch: 1510000, loss:-0.0000220, const:0.0000, lowest:0.0000, co:0, bug:452
# Epoch: 1520000, loss:0.0002611, const:0.0000, lowest:0.0000, co:0, bug:454
# Epoch: 1530000, loss:-0.0000676, const:0.0000, lowest:0.0000, co:0, bug:457
# Epoch: 1540000, loss:-0.0000278, const:0.0000, lowest:0.0000, co:0, bug:460
# Epoch: 1550000, loss:-0.0000524, const:0.0000, lowest:0.0000, co:0, bug:462
# Epoch: 1560000, loss:0.0000025, const:0.0000, lowest:0.0000, co:0, bug:465
# Epoch: 1570000, loss:0.0000389, const:0.0000, lowest:0.0000, co:0, bug:467
# Epoch: 1580000, loss:0.0001682, const:0.0000, lowest:0.0000, co:0, bug:469
# Epoch: 1590000, loss:-0.0000009, const:0.0000, lowest:0.0000, co:0, bug:470
# Epoch: 1600000, loss:-0.0000344, const:0.0000, lowest:0.0000, co:0, bug:473
# Epoch: 1610000, loss:0.0005116, const:0.0000, lowest:0.0000, co:0, bug:478
# Epoch: 1620000, loss:0.0000058, const:0.0000, lowest:0.0000, co:0, bug:482
# Epoch: 1630000, loss:-0.0000544, const:0.0000, lowest:0.0000, co:0, bug:486
# Epoch: 1640000, loss:-0.0000555, const:0.0000, lowest:0.0000, co:0, bug:490
# Epoch: 1650000, loss:0.0000076, const:0.0000, lowest:0.0000, co:0, bug:491
# Epoch: 1660000, loss:0.0001956, const:0.0000, lowest:0.0000, co:0, bug:494
# Epoch: 1670000, loss:-0.0000414, const:0.0000, lowest:0.0000, co:0, bug:500
# Epoch: 1680000, loss:0.0000120, const:0.0000, lowest:0.0000, co:0, bug:501
# Epoch: 1690000, loss:0.0000300, const:0.0000, lowest:0.0000, co:0, bug:503
# Epoch: 1700000, loss:-0.0000255, const:0.0000, lowest:0.0000, co:0, bug:508
# Epoch: 1710000, loss:-0.0000958, const:0.0000, lowest:0.0000, co:0, bug:510
# Epoch: 1720000, loss:-0.0001656, const:0.0000, lowest:0.0000, co:0, bug:514
# Epoch: 1730000, loss:0.0000206, const:0.0000, lowest:0.0000, co:0, bug:516
# Epoch: 1740000, loss:0.0000611, const:0.0000, lowest:0.0000, co:0, bug:521
# Epoch: 1750000, loss:0.0000997, const:0.0000, lowest:0.0000, co:0, bug:523
# Epoch: 1760000, loss:0.0000403, const:0.0000, lowest:0.0000, co:0, bug:525
# Epoch: 1770000, loss:0.0000433, const:0.0000, lowest:0.0000, co:0, bug:527
# Epoch: 1780000, loss:0.0001054, const:0.0000, lowest:0.0000, co:0, bug:533
# Epoch: 1790000, loss:-0.0000094, const:0.0000, lowest:0.0000, co:0, bug:534
# Epoch: 1800000, loss:0.0000517, const:0.0000, lowest:0.0000, co:0, bug:538
# Epoch: 1810000, loss:-0.0000714, const:0.0000, lowest:0.0000, co:0, bug:542
# Epoch: 1820000, loss:-0.0000524, const:0.0000, lowest:0.0000, co:0, bug:544
# Epoch: 1830000, loss:0.0000262, const:0.0000, lowest:0.0000, co:0, bug:546
# Epoch: 1840000, loss:0.0000791, const:0.0000, lowest:0.0000, co:0, bug:549
# Epoch: 1850000, loss:-0.0001449, const:0.0000, lowest:0.0000, co:0, bug:551
# Epoch: 1860000, loss:0.0004506, const:0.0000, lowest:0.0000, co:0, bug:554
# Epoch: 1870000, loss:0.0000388, const:0.0000, lowest:0.0000, co:0, bug:556
# Epoch: 1880000, loss:0.0003468, const:0.0000, lowest:0.0000, co:0, bug:559
# Epoch: 1890000, loss:-0.0000154, const:0.0000, lowest:0.0000, co:0, bug:565
# Epoch: 1900000, loss:-0.0000736, const:0.0000, lowest:0.0000, co:0, bug:566
# Epoch: 1910000, loss:0.0000757, const:0.0000, lowest:0.0000, co:0, bug:568
# Epoch: 1920000, loss:-0.0001475, const:0.0000, lowest:0.0000, co:0, bug:569
# Epoch: 1930000, loss:0.0002988, const:0.0000, lowest:0.0000, co:0, bug:570
# Epoch: 1940000, loss:0.0000191, const:0.0000, lowest:0.0000, co:0, bug:574
# Epoch: 1950000, loss:-0.0002387, const:0.0000, lowest:0.0000, co:0, bug:578
# Epoch: 1960000, loss:0.0000714, const:0.0000, lowest:0.0000, co:0, bug:581
# Epoch: 1970000, loss:0.0001323, const:0.0000, lowest:0.0000, co:0, bug:586
# Epoch: 1980000, loss:0.0000634, const:0.0000, lowest:0.0000, co:0, bug:590
# Epoch: 1990000, loss:0.0000939, const:0.0000, lowest:0.0000, co:0, bug:591
