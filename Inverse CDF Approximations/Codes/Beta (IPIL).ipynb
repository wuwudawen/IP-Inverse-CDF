# %%
import jax
import jax.numpy as jnp
from jax import jit, vmap, grad
from jax import random
import optax
import numpy as np
import pickle
from scipy.stats import beta as beta_dist
alpha=2.7
beta=3.9

# %%
def init_network_params(sizes, key=random.PRNGKey(4)):
    def random_layer_params(m, n, key, scale=1e-2):
        w_key, b_key = random.split(key)
        return scale * random.uniform(w_key, (n, m), minval=1, maxval=3), scale * random.uniform(b_key, (n,), minval=1, maxval=3)

    keys = random.split(key, len(sizes))
    return [random_layer_params(m, n, k) for m, n, k in zip(sizes[:-1], sizes[1:], keys)]

def predict_(NN, u):
    activations = u.reshape((-1, ))
    activations = jnp.log(activations/(1-activations))
    for w, b in NN[:-1]:
        outputs = jnp.dot(w, activations) + b
        activations = jax.nn.sigmoid(outputs)
    final_w, final_b = NN[-1]
    logit = jnp.dot(final_w, activations) + final_b
    return logit.squeeze()

def predict(NN, u):
    return predict_(NN, u) + beta_dist.ppf(0.5, alpha, beta) - predict_(NN, np.array([0.5]))

vpredict = vmap(predict, in_axes=(None, 0))
gpredict = grad(predict, argnums=1)
vgpredict = jit(vmap(gpredict, in_axes=(None, 0)))

# %%
def pi(x):
    from scipy.special import gamma
    B_ab = (gamma(alpha) * gamma(beta)) / gamma(alpha + beta)
    pdf = (x**(alpha - 1)) * ((1 - x)**(beta - 1)) / B_ab
    return pdf
vpi = vmap(pi, in_axes=(0,))

@jit
def obj(NN, test_uz):
    def ell(NN, uz):
        u, z = uz
        return jnp.square(gpredict(NN, u)-1/pi(z))
    vell = vmap(ell, in_axes=(None, 0))

    result = vell(NN, test_uz)
    result = jnp.mean(result)
    return result

@jit
def constraint(NN, test_uz):
    u_batch, z_batch = test_uz[:, 0], test_uz[:, 1]
    epsilon = 1e-12
    def g(NN, u):
        return jnp.maximum(-gpredict(NN, u)+epsilon, 0)
    vg = vmap(g, in_axes=(None, 0))

    result = vg(NN, u_batch)
    result = jnp.sum(result)
    return result

gobj = jit(grad(obj))
gconst = jit(grad(constraint))

@jit
def evaluation(NN, test_uz):
    u_batch, z_batch = test_uz[:, 0], test_uz[:, 1]
    result = jnp.square(vpredict(NN, u_batch) - z_batch)
    result = jnp.mean(result)
    return result

# %%
# def gen_uz_batch(N=10000):
#     import jax.numpy as jnp
#     import jax.random as random
#     from jax.scipy.stats import beta

#     key = random.PRNGKey(0)
#     a = 2.7  # Alpha 参数
#     b = 3.9  # Beta 参数
#     z = random.beta(key, a=a, b=b, shape=(N,))
#     u = beta.cdf(z, a=a, b=b)
#     uz_batch = jnp.stack((u, z), axis=-1)
#     return uz_batch
# train_uz = gen_uz_batch(N=10000)
# np.save('/content/drive/MyDrive/No. 22 Physica D (inverse)/Beta checkpoints (PINN)/train_uz.npy', train_uz)

# %%
LAYER_SIZES = [1, 10, 10, 10, 1]
NN = init_network_params(LAYER_SIZES, random.PRNGKey(15))

optimizer= optax.adam(0.001)
opt_state = optimizer.init(NN)
bug = 0
co = 0
test_uz = np.load(f'/content/drive/MyDrive/No. 22 Physica D (inverse)/Beta checkpoints (PINN)/test_uz.npy')
train_uz = np.load(f'/content/drive/MyDrive/No. 22 Physica D (inverse)/Beta checkpoints (PINN)/train_uz.npy')
lowest = evaluation(NN, test_uz)
Lloss = []
Llowest = []
NN_best = NN
for epoch in range(2000000):
    while constraint(NN, train_uz).item()>0:
        grads = gconst(NN, train_uz)
        updates, opt_state = optimizer.update(grads, opt_state)
        NN = optax.apply_updates(NN, updates)
        co += 1

    grads = gobj(NN, train_uz)
    updates, opt_state = optimizer.update(grads, opt_state)
    NN = optax.apply_updates(NN, updates)

    Lloss.append(obj(NN, train_uz).item())
    Llowest.append(lowest.item())

    if  evaluation(NN, test_uz)<lowest:
        lowest = evaluation(NN, test_uz)
        NN_best = NN

    if epoch % 10000 == 0:
        print(f"Epoch: {epoch}, loss:{obj(NN, train_uz).item():.7f}, const:{constraint(NN, train_uz).item():.4f}, lowest:{lowest:.4f}, co:{co}, bug:{bug}")
        np.save(f'/content/drive/MyDrive/No. 22 Physica D (inverse)/Beta checkpoints (PINN)/Lloss.npy', Lloss)
        np.save(f'/content/drive/MyDrive/No. 22 Physica D (inverse)/Beta checkpoints (PINN)/Llowest.npy', Llowest)
        with open(f'/content/drive/MyDrive/No. 22 Physica D (inverse)/Beta checkpoints (PINN)/NN (best).pkl', 'wb') as f:
            pickle.dump(NN_best, f)
        with open(f'/content/drive/MyDrive/No. 22 Physica D (inverse)/Beta checkpoints (PINN)/NN_{epoch}.pkl', 'wb') as f:
            pickle.dump(NN, f)
# Out:
# Epoch: 0, loss:7.2738004, const:0.0000, lowest:0.0314, co:0, bug:0
# Epoch: 10000, loss:0.0000060, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 20000, loss:0.0000007, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 30000, loss:0.0000003, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 40000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 50000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 60000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 70000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 80000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 90000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 100000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 110000, loss:0.0000009, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 120000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 130000, loss:0.0000038, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 140000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 150000, loss:0.0000003, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 160000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 170000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 180000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 190000, loss:0.0000003, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 200000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 210000, loss:0.0000003, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 220000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 230000, loss:0.0000022, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 240000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 250000, loss:0.0000006, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 260000, loss:0.0000020, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 270000, loss:0.0000007, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 280000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 290000, loss:0.0000002, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 300000, loss:0.0000006, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 310000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 320000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 330000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 340000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 350000, loss:0.0000002, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 360000, loss:0.0000002, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 370000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 380000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 390000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 400000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 410000, loss:0.0000004, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 420000, loss:0.0000007, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 430000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 440000, loss:0.0000029, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 450000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 460000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 470000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 480000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 490000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 500000, loss:0.0000021, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 510000, loss:0.0000007, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 520000, loss:0.0000028, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 530000, loss:0.0000006, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 540000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 550000, loss:0.0000002, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 560000, loss:0.0000006, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 570000, loss:0.0000015, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 580000, loss:0.0000009, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 590000, loss:0.0000003, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 600000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 610000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 620000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 630000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 640000, loss:0.0000003, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 650000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 660000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 670000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 680000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 690000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 700000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 710000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 720000, loss:0.0000011, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 730000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 740000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 750000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 760000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 770000, loss:0.0000002, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 780000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 790000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 800000, loss:0.0000005, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 810000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 820000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 830000, loss:0.0000008, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 840000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 850000, loss:0.0000004, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 860000, loss:0.0000015, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 870000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 880000, loss:0.0000004, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 890000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 900000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 910000, loss:0.0000006, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 920000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 930000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 940000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 950000, loss:0.0000055, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 960000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 970000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 980000, loss:0.0000002, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 990000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1000000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1010000, loss:0.0000008, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1020000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1030000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1040000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1050000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1060000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1070000, loss:0.0000005, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1080000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1090000, loss:0.0000002, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1100000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1110000, loss:0.0000078, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1120000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1130000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1140000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1150000, loss:0.0000002, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1160000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1170000, loss:0.0000013, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1180000, loss:0.0000050, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1190000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1200000, loss:0.0000047, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1210000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1220000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1230000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1240000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1250000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1260000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1270000, loss:0.0000002, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1280000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1290000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1300000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1310000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1320000, loss:0.0000017, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1330000, loss:0.0000019, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1340000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1350000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1360000, loss:0.0000012, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1370000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1380000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1390000, loss:0.0000070, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1400000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1410000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1420000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1430000, loss:0.0000013, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1440000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1450000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1460000, loss:0.0000003, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1470000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1480000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1490000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1500000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1510000, loss:0.0000004, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1520000, loss:0.0000011, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1530000, loss:0.0000013, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1540000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1550000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1560000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1570000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1580000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1590000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1600000, loss:0.0000004, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1610000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1620000, loss:0.0000008, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1630000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1640000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1650000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1660000, loss:0.0000010, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1670000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1680000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1690000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1700000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1710000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1720000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1730000, loss:0.0000002, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1740000, loss:0.0000006, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1750000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1760000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1770000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1780000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1790000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1800000, loss:0.0000004, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1810000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1820000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1830000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1840000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1850000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1860000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1870000, loss:0.0000044, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1880000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1890000, loss:0.0000007, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1900000, loss:0.0000001, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1910000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1920000, loss:0.0000002, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1930000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1940000, loss:0.0000019, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1950000, loss:0.0000009, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1960000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1970000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1980000, loss:0.0000014, const:0.0000, lowest:0.0000, co:0, bug:0
# Epoch: 1990000, loss:0.0000000, const:0.0000, lowest:0.0000, co:0, bug:0
