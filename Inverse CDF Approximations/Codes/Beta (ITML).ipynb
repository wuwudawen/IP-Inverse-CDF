# %%
import jax
import jax.numpy as jnp
from jax import jit, vmap, grad
from jax import random
import optax
import numpy as np
import pickle

# %%
def init_network_params(sizes, key=random.PRNGKey(4)):
    def random_layer_params(m, n, key, scale=1e-2):
        w_key, b_key = random.split(key)
        return scale * random.uniform(w_key, (n, m), minval=1, maxval=3), scale * random.uniform(b_key, (n,), minval=1, maxval=3)

    keys = random.split(key, len(sizes))
    return [random_layer_params(m, n, k) for m, n, k in zip(sizes[:-1], sizes[1:], keys)]

def predict(NN, u):
    activations = u.reshape((-1, ))
    activations = jnp.log(activations/(1-activations))
    for w, b in NN[:-1]:
        outputs = jnp.dot(w, activations) + b
        activations = jax.nn.sigmoid(outputs)
    final_w, final_b = NN[-1]
    logit = jnp.dot(final_w, activations) + final_b
    return logit.squeeze()

vpredict = vmap(predict, in_axes=(None, 0))
gpredict = grad(predict, argnums=1)
vgpredict = jit(vmap(gpredict, in_axes=(None, 0)))

# %%
def pi(x):
    from jax import numpy as jnp
    from jax import lax
    from jax.scipy.special import gamma
    alpha = 2.7
    beta = 3.9
    B_ab = (gamma(alpha) * gamma(beta)) / gamma(alpha + beta)
    pdf = lax.cond(
        (x >= 0) & (x <= 1),
        lambda x: (x ** (alpha - 1)) * ((1 - x) ** (beta - 1)) / B_ab,
        lambda x: 0.0,
        x
    )
    return pdf

vpi = vmap(pi, in_axes=(0,))

@jit
def obj(NN, u_batch):
    def ell(NN, u):
        return -jnp.log(pi(predict(NN, u))) - jnp.log(gpredict(NN, u))
    vell = vmap(ell, in_axes=(None, 0))

    result = vell(NN, u_batch)
    result = jnp.mean(result)
    return result

@jit
def constraint(NN, u_batch):
    epsilon = 1e-12
    def g(NN, u):
        return jnp.maximum(-gpredict(NN, u)+epsilon, 0)
    vg = vmap(g, in_axes=(None, 0))

    result = vg(NN, u_batch)
    result = jnp.sum(result)
    return result

gobj = jit(grad(obj))
gconst = jit(grad(constraint))

@jit
def evaluation(NN, test_uz):
    u_batch, z_batch = test_uz[:, 0], test_uz[:, 1]
    result = jnp.square(vpredict(NN, u_batch) - z_batch)
    result = jnp.mean(result)
    return result

# %%
LAYER_SIZES = [1, 10, 10, 10, 1]
NN = init_network_params(LAYER_SIZES, random.PRNGKey(14))

optimizer= optax.adam(0.001)
opt_state = optimizer.init(NN)
bug = 0
co = 0
test_uz = np.load(f'/content/drive/MyDrive/No. 22 Physica D (inverse)/Beta checkpoints (TM)/test_uz.npy')
lowest = evaluation(NN, test_uz)
Lloss = []
Llowest = []
NN_best = NN
for epoch in range(2000000):
    u_batch = np.random.uniform(0, 1, (10000, 1))
    while jnp.isnan(vgpredict(NN, u_batch)).sum() != 0:
        u_batch = np.random.uniform(0, 1, (10000, 1))
        bug += 1

    while constraint(NN, u_batch).item()>0:
        grads = gconst(NN, u_batch)
        updates, opt_state = optimizer.update(grads, opt_state)
        NN = optax.apply_updates(NN, updates)
        co += 1

    grads = gobj(NN, u_batch)
    updates, opt_state = optimizer.update(grads, opt_state)
    NN = optax.apply_updates(NN, updates)

    Lloss.append(obj(NN, u_batch).item())
    Llowest.append(lowest.item())

    if  evaluation(NN, test_uz)<lowest:
        lowest = evaluation(NN, test_uz)
        NN_best = NN

    if epoch % 10000 == 0:
        print(f"Epoch: {epoch}, loss:{obj(NN, u_batch).item():.7f}, const:{constraint(NN, u_batch).item():.4f}, lowest:{lowest:.4f}, co:{co}, bug:{bug}")
        np.save(f'/content/drive/MyDrive/No. 22 Physica D (inverse)/Beta checkpoints (TM)/Lloss.npy', Lloss)
        np.save(f'/content/drive/MyDrive/No. 22 Physica D (inverse)/Beta checkpoints (TM)/Llowest.npy', Llowest)
        with open(f'/content/drive/MyDrive/No. 22 Physica D (inverse)/Beta checkpoints (TM)/NN (best).pkl', 'wb') as f:
            pickle.dump(NN_best, f)
        with open(f'/content/drive/MyDrive/No. 22 Physica D (inverse)/Beta checkpoints (TM)/NN_{epoch}.pkl', 'wb') as f:
            pickle.dump(NN, f)
# Out:
# Epoch: 0, loss:10.9047060, const:0.0000, lowest:0.1066, co:0, bug:0
# Epoch: 10000, loss:0.0002010, const:0.0000, lowest:0.0000, co:0, bug:3
# Epoch: 20000, loss:0.0003635, const:0.0000, lowest:0.0000, co:0, bug:7
# Epoch: 30000, loss:0.0004861, const:0.0000, lowest:0.0000, co:0, bug:11
# Epoch: 40000, loss:0.0000485, const:0.0000, lowest:0.0000, co:0, bug:16
# Epoch: 50000, loss:-0.0000311, const:0.0000, lowest:0.0000, co:0, bug:18
# Epoch: 60000, loss:0.0003367, const:0.0000, lowest:0.0000, co:0, bug:20
# Epoch: 70000, loss:0.0000304, const:0.0000, lowest:0.0000, co:0, bug:21
# Epoch: 80000, loss:-0.0001305, const:0.0000, lowest:0.0000, co:0, bug:23
# Epoch: 90000, loss:-0.0000400, const:0.0000, lowest:0.0000, co:0, bug:31
# Epoch: 100000, loss:0.0001369, const:0.0000, lowest:0.0000, co:0, bug:35
# Epoch: 110000, loss:-0.0000090, const:0.0000, lowest:0.0000, co:0, bug:37
# Epoch: 120000, loss:0.0002632, const:0.0000, lowest:0.0000, co:0, bug:40
# Epoch: 130000, loss:0.0001659, const:0.0000, lowest:0.0000, co:0, bug:42
# Epoch: 140000, loss:0.0000235, const:0.0000, lowest:0.0000, co:0, bug:42
# Epoch: 150000, loss:0.0001797, const:0.0000, lowest:0.0000, co:0, bug:47
# Epoch: 160000, loss:0.0007390, const:0.0000, lowest:0.0000, co:0, bug:48
# Epoch: 170000, loss:0.0000969, const:0.0000, lowest:0.0000, co:0, bug:52
# Epoch: 180000, loss:0.0001349, const:0.0000, lowest:0.0000, co:0, bug:55
# Epoch: 190000, loss:0.0004872, const:0.0000, lowest:0.0000, co:0, bug:58
# Epoch: 200000, loss:0.0003114, const:0.0000, lowest:0.0000, co:0, bug:61
# Epoch: 210000, loss:0.0002569, const:0.0000, lowest:0.0000, co:0, bug:61
# Epoch: 220000, loss:0.0000311, const:0.0000, lowest:0.0000, co:0, bug:67
# Epoch: 230000, loss:0.0004608, const:0.0000, lowest:0.0000, co:0, bug:68
# Epoch: 240000, loss:0.0004721, const:0.0000, lowest:0.0000, co:0, bug:70
# Epoch: 250000, loss:-0.0004468, const:0.0000, lowest:0.0000, co:0, bug:72
# Epoch: 260000, loss:-0.0001253, const:0.0000, lowest:0.0000, co:0, bug:77
# Epoch: 270000, loss:0.0001369, const:0.0000, lowest:0.0000, co:0, bug:79
# Epoch: 280000, loss:0.0001126, const:0.0000, lowest:0.0000, co:0, bug:82
# Epoch: 290000, loss:-0.0000797, const:0.0000, lowest:0.0000, co:0, bug:87
# Epoch: 300000, loss:0.0000764, const:0.0000, lowest:0.0000, co:0, bug:89
# Epoch: 310000, loss:0.0000800, const:0.0000, lowest:0.0000, co:0, bug:92
# Epoch: 320000, loss:-0.0001494, const:0.0000, lowest:0.0000, co:0, bug:100
# Epoch: 330000, loss:0.0004776, const:0.0000, lowest:0.0000, co:0, bug:102
# Epoch: 340000, loss:-0.0000149, const:0.0000, lowest:0.0000, co:0, bug:104
# Epoch: 350000, loss:-0.0000089, const:0.0000, lowest:0.0000, co:0, bug:104
# Epoch: 360000, loss:0.0001756, const:0.0000, lowest:0.0000, co:0, bug:109
# Epoch: 370000, loss:0.0000754, const:0.0000, lowest:0.0000, co:0, bug:113
# Epoch: 380000, loss:0.0003918, const:0.0000, lowest:0.0000, co:0, bug:117
# Epoch: 390000, loss:0.0002069, const:0.0000, lowest:0.0000, co:0, bug:121
# Epoch: 400000, loss:0.0000164, const:0.0000, lowest:0.0000, co:0, bug:122
# Epoch: 410000, loss:0.0000284, const:0.0000, lowest:0.0000, co:0, bug:125
# Epoch: 420000, loss:0.0000491, const:0.0000, lowest:0.0000, co:0, bug:129
# Epoch: 430000, loss:0.0000249, const:0.0000, lowest:0.0000, co:0, bug:131
# Epoch: 440000, loss:-0.0000030, const:0.0000, lowest:0.0000, co:0, bug:132
# Epoch: 450000, loss:-0.0001030, const:0.0000, lowest:0.0000, co:0, bug:137
# Epoch: 460000, loss:-0.0000514, const:0.0000, lowest:0.0000, co:0, bug:140
# Epoch: 470000, loss:0.0001547, const:0.0000, lowest:0.0000, co:0, bug:142
# Epoch: 480000, loss:0.0002887, const:0.0000, lowest:0.0000, co:0, bug:144
# Epoch: 490000, loss:-0.0000384, const:0.0000, lowest:0.0000, co:0, bug:147
# Epoch: 500000, loss:0.0002653, const:0.0000, lowest:0.0000, co:0, bug:148
# Epoch: 510000, loss:0.0001599, const:0.0000, lowest:0.0000, co:0, bug:150
# Epoch: 520000, loss:0.0005529, const:0.0000, lowest:0.0000, co:0, bug:151
# Epoch: 530000, loss:0.0000504, const:0.0000, lowest:0.0000, co:0, bug:154
# Epoch: 540000, loss:0.0000310, const:0.0000, lowest:0.0000, co:0, bug:158
# Epoch: 550000, loss:0.0000654, const:0.0000, lowest:0.0000, co:0, bug:161
# Epoch: 560000, loss:0.0003461, const:0.0000, lowest:0.0000, co:0, bug:164
# Epoch: 570000, loss:0.0000990, const:0.0000, lowest:0.0000, co:0, bug:169
# Epoch: 580000, loss:0.0002284, const:0.0000, lowest:0.0000, co:0, bug:171
# Epoch: 590000, loss:0.0001195, const:0.0000, lowest:0.0000, co:0, bug:173
# Epoch: 600000, loss:0.0000622, const:0.0000, lowest:0.0000, co:0, bug:176
# Epoch: 610000, loss:-0.0000109, const:0.0000, lowest:0.0000, co:0, bug:177
# Epoch: 620000, loss:0.0000005, const:0.0000, lowest:0.0000, co:0, bug:182
# Epoch: 630000, loss:0.0000322, const:0.0000, lowest:0.0000, co:0, bug:187
# Epoch: 640000, loss:-0.0000559, const:0.0000, lowest:0.0000, co:0, bug:189
# Epoch: 650000, loss:-0.0000114, const:0.0000, lowest:0.0000, co:0, bug:191
# Epoch: 660000, loss:-0.0000990, const:0.0000, lowest:0.0000, co:0, bug:194
# Epoch: 670000, loss:0.0000314, const:0.0000, lowest:0.0000, co:0, bug:194
# Epoch: 680000, loss:0.0001193, const:0.0000, lowest:0.0000, co:0, bug:195
# Epoch: 690000, loss:0.0000118, const:0.0000, lowest:0.0000, co:0, bug:199
# Epoch: 700000, loss:-0.0000849, const:0.0000, lowest:0.0000, co:0, bug:200
# Epoch: 710000, loss:-0.0001750, const:0.0000, lowest:0.0000, co:0, bug:203
# Epoch: 720000, loss:0.0000453, const:0.0000, lowest:0.0000, co:0, bug:206
# Epoch: 730000, loss:-0.0000691, const:0.0000, lowest:0.0000, co:0, bug:209
# Epoch: 740000, loss:0.0001517, const:0.0000, lowest:0.0000, co:0, bug:209
# Epoch: 750000, loss:0.0000588, const:0.0000, lowest:0.0000, co:0, bug:212
# Epoch: 760000, loss:0.0000782, const:0.0000, lowest:0.0000, co:0, bug:213
# Epoch: 770000, loss:-0.0000965, const:0.0000, lowest:0.0000, co:0, bug:217
# Epoch: 780000, loss:-0.0001100, const:0.0000, lowest:0.0000, co:0, bug:220
# Epoch: 790000, loss:0.0001546, const:0.0000, lowest:0.0000, co:0, bug:225
# Epoch: 800000, loss:-0.0000695, const:0.0000, lowest:0.0000, co:0, bug:231
# Epoch: 810000, loss:-0.0000646, const:0.0000, lowest:0.0000, co:0, bug:233
# Epoch: 820000, loss:0.0000397, const:0.0000, lowest:0.0000, co:0, bug:236
# Epoch: 830000, loss:0.0000349, const:0.0000, lowest:0.0000, co:0, bug:237
# Epoch: 840000, loss:-0.0000215, const:0.0000, lowest:0.0000, co:0, bug:238
# Epoch: 850000, loss:0.0003133, const:0.0000, lowest:0.0000, co:0, bug:240
# Epoch: 860000, loss:0.0000318, const:0.0000, lowest:0.0000, co:0, bug:240
# Epoch: 870000, loss:0.0001506, const:0.0000, lowest:0.0000, co:0, bug:242
# Epoch: 880000, loss:0.0000720, const:0.0000, lowest:0.0000, co:0, bug:246
# Epoch: 890000, loss:-0.0000003, const:0.0000, lowest:0.0000, co:0, bug:248
# Epoch: 900000, loss:0.0002878, const:0.0000, lowest:0.0000, co:0, bug:249
# Epoch: 910000, loss:-0.0000325, const:0.0000, lowest:0.0000, co:0, bug:254
# Epoch: 920000, loss:0.0002471, const:0.0000, lowest:0.0000, co:0, bug:256
# Epoch: 930000, loss:-0.0001091, const:0.0000, lowest:0.0000, co:0, bug:257
# Epoch: 940000, loss:0.0003862, const:0.0000, lowest:0.0000, co:0, bug:259
# Epoch: 950000, loss:0.0001539, const:0.0000, lowest:0.0000, co:0, bug:261
# Epoch: 960000, loss:0.0000250, const:0.0000, lowest:0.0000, co:0, bug:263
# Epoch: 970000, loss:-0.0000674, const:0.0000, lowest:0.0000, co:0, bug:265
# Epoch: 980000, loss:0.0000681, const:0.0000, lowest:0.0000, co:0, bug:268
# Epoch: 990000, loss:-0.0000902, const:0.0000, lowest:0.0000, co:0, bug:274
# Epoch: 1000000, loss:-0.0000508, const:0.0000, lowest:0.0000, co:0, bug:277
# Epoch: 1010000, loss:0.0000890, const:0.0000, lowest:0.0000, co:0, bug:279
# Epoch: 1020000, loss:0.0000875, const:0.0000, lowest:0.0000, co:0, bug:281
# Epoch: 1030000, loss:0.0000725, const:0.0000, lowest:0.0000, co:0, bug:281
# Epoch: 1040000, loss:0.0000880, const:0.0000, lowest:0.0000, co:0, bug:288
# Epoch: 1050000, loss:0.0000106, const:0.0000, lowest:0.0000, co:0, bug:291
# Epoch: 1060000, loss:-0.0000952, const:0.0000, lowest:0.0000, co:0, bug:294
# Epoch: 1070000, loss:0.0000971, const:0.0000, lowest:0.0000, co:0, bug:299
# Epoch: 1080000, loss:-0.0000280, const:0.0000, lowest:0.0000, co:0, bug:302
# Epoch: 1090000, loss:0.0002768, const:0.0000, lowest:0.0000, co:0, bug:306
# Epoch: 1100000, loss:-0.0000088, const:0.0000, lowest:0.0000, co:0, bug:309
# Epoch: 1110000, loss:0.0000079, const:0.0000, lowest:0.0000, co:0, bug:314
# Epoch: 1120000, loss:0.0038783, const:0.0000, lowest:0.0000, co:0, bug:315
# Epoch: 1130000, loss:0.0000299, const:0.0000, lowest:0.0000, co:0, bug:317
# Epoch: 1140000, loss:0.0000149, const:0.0000, lowest:0.0000, co:0, bug:321
# Epoch: 1150000, loss:0.0000119, const:0.0000, lowest:0.0000, co:0, bug:324
# Epoch: 1160000, loss:0.0002574, const:0.0000, lowest:0.0000, co:0, bug:329
# Epoch: 1170000, loss:0.0002333, const:0.0000, lowest:0.0000, co:0, bug:332
# Epoch: 1180000, loss:0.0004658, const:0.0000, lowest:0.0000, co:0, bug:333
# Epoch: 1190000, loss:0.0000853, const:0.0000, lowest:0.0000, co:0, bug:337
# Epoch: 1200000, loss:-0.0001535, const:0.0000, lowest:0.0000, co:0, bug:341
# Epoch: 1210000, loss:0.0000817, const:0.0000, lowest:0.0000, co:0, bug:343
# Epoch: 1220000, loss:0.0000194, const:0.0000, lowest:0.0000, co:0, bug:346
# Epoch: 1230000, loss:-0.0002567, const:0.0000, lowest:0.0000, co:0, bug:347
# Epoch: 1240000, loss:0.0000107, const:0.0000, lowest:0.0000, co:0, bug:350
# Epoch: 1250000, loss:-0.0000218, const:0.0000, lowest:0.0000, co:0, bug:356
# Epoch: 1260000, loss:0.0000137, const:0.0000, lowest:0.0000, co:0, bug:363
# Epoch: 1270000, loss:0.0000202, const:0.0000, lowest:0.0000, co:0, bug:364
# Epoch: 1280000, loss:0.0001203, const:0.0000, lowest:0.0000, co:0, bug:369
# Epoch: 1290000, loss:0.0000030, const:0.0000, lowest:0.0000, co:0, bug:372
# Epoch: 1300000, loss:0.0000638, const:0.0000, lowest:0.0000, co:0, bug:377
# Epoch: 1310000, loss:-0.0002364, const:0.0000, lowest:0.0000, co:0, bug:381
# Epoch: 1320000, loss:0.0000843, const:0.0000, lowest:0.0000, co:0, bug:385
# Epoch: 1330000, loss:-0.0000557, const:0.0000, lowest:0.0000, co:0, bug:390
# Epoch: 1340000, loss:-0.0000062, const:0.0000, lowest:0.0000, co:0, bug:394
# Epoch: 1350000, loss:-0.0000268, const:0.0000, lowest:0.0000, co:0, bug:397
# Epoch: 1360000, loss:0.0001198, const:0.0000, lowest:0.0000, co:0, bug:399
# Epoch: 1370000, loss:0.0001972, const:0.0000, lowest:0.0000, co:0, bug:400
# Epoch: 1380000, loss:-0.0000338, const:0.0000, lowest:0.0000, co:0, bug:403
# Epoch: 1390000, loss:0.0005699, const:0.0000, lowest:0.0000, co:0, bug:406
# Epoch: 1400000, loss:-0.0000596, const:0.0000, lowest:0.0000, co:0, bug:409
# Epoch: 1410000, loss:0.0000607, const:0.0000, lowest:0.0000, co:0, bug:413
# Epoch: 1420000, loss:0.0000259, const:0.0000, lowest:0.0000, co:0, bug:417
# Epoch: 1430000, loss:-0.0000470, const:0.0000, lowest:0.0000, co:0, bug:420
# Epoch: 1440000, loss:0.0001121, const:0.0000, lowest:0.0000, co:0, bug:423
# Epoch: 1450000, loss:0.0000978, const:0.0000, lowest:0.0000, co:0, bug:424
# Epoch: 1460000, loss:-0.0000106, const:0.0000, lowest:0.0000, co:0, bug:427
# Epoch: 1470000, loss:0.0000801, const:0.0000, lowest:0.0000, co:0, bug:434
# Epoch: 1480000, loss:0.0000669, const:0.0000, lowest:0.0000, co:0, bug:435
# Epoch: 1490000, loss:0.0000237, const:0.0000, lowest:0.0000, co:0, bug:438
# Epoch: 1500000, loss:-0.0000094, const:0.0000, lowest:0.0000, co:0, bug:439
# Epoch: 1510000, loss:0.0000120, const:0.0000, lowest:0.0000, co:0, bug:441
# Epoch: 1520000, loss:-0.0000228, const:0.0000, lowest:0.0000, co:0, bug:446
# Epoch: 1530000, loss:-0.0001186, const:0.0000, lowest:0.0000, co:0, bug:447
# Epoch: 1540000, loss:-0.0000206, const:0.0000, lowest:0.0000, co:0, bug:449
# Epoch: 1550000, loss:0.0000783, const:0.0000, lowest:0.0000, co:0, bug:451
# Epoch: 1560000, loss:0.0001396, const:0.0000, lowest:0.0000, co:0, bug:455
# Epoch: 1570000, loss:-0.0000482, const:0.0000, lowest:0.0000, co:0, bug:458
# Epoch: 1580000, loss:-0.0000621, const:0.0000, lowest:0.0000, co:0, bug:464
# Epoch: 1590000, loss:0.0000965, const:0.0000, lowest:0.0000, co:0, bug:467
# Epoch: 1600000, loss:0.0000584, const:0.0000, lowest:0.0000, co:0, bug:471
# Epoch: 1610000, loss:-0.0000714, const:0.0000, lowest:0.0000, co:0, bug:476
# Epoch: 1620000, loss:0.0000498, const:0.0000, lowest:0.0000, co:0, bug:479
# Epoch: 1630000, loss:-0.0000335, const:0.0000, lowest:0.0000, co:0, bug:483
# Epoch: 1640000, loss:0.0001885, const:0.0000, lowest:0.0000, co:0, bug:484
# Epoch: 1650000, loss:0.0001701, const:0.0000, lowest:0.0000, co:0, bug:484
# Epoch: 1660000, loss:0.0000008, const:0.0000, lowest:0.0000, co:0, bug:485
# Epoch: 1670000, loss:0.0002191, const:0.0000, lowest:0.0000, co:0, bug:487
# Epoch: 1680000, loss:0.0003258, const:0.0000, lowest:0.0000, co:0, bug:492
# Epoch: 1690000, loss:-0.0000172, const:0.0000, lowest:0.0000, co:0, bug:494
# Epoch: 1700000, loss:-0.0000683, const:0.0000, lowest:0.0000, co:0, bug:496
# Epoch: 1710000, loss:0.0004889, const:0.0000, lowest:0.0000, co:0, bug:499
# Epoch: 1720000, loss:0.0002039, const:0.0000, lowest:0.0000, co:0, bug:504
# Epoch: 1730000, loss:-0.0000817, const:0.0000, lowest:0.0000, co:0, bug:505
# Epoch: 1740000, loss:0.0000081, const:0.0000, lowest:0.0000, co:0, bug:509
# Epoch: 1750000, loss:0.0003530, const:0.0000, lowest:0.0000, co:0, bug:512
# Epoch: 1760000, loss:0.0000477, const:0.0000, lowest:0.0000, co:0, bug:514
# Epoch: 1770000, loss:0.0000445, const:0.0000, lowest:0.0000, co:0, bug:516
# Epoch: 1780000, loss:-0.0000532, const:0.0000, lowest:0.0000, co:0, bug:520
# Epoch: 1790000, loss:-0.0000055, const:0.0000, lowest:0.0000, co:0, bug:523
# Epoch: 1800000, loss:0.0001378, const:0.0000, lowest:0.0000, co:0, bug:524
# Epoch: 1810000, loss:0.0001270, const:0.0000, lowest:0.0000, co:0, bug:527
# Epoch: 1820000, loss:0.0000081, const:0.0000, lowest:0.0000, co:0, bug:528
# Epoch: 1830000, loss:-0.0000326, const:0.0000, lowest:0.0000, co:0, bug:530
# Epoch: 1840000, loss:0.0015325, const:0.0000, lowest:0.0000, co:0, bug:532
# Epoch: 1850000, loss:0.0001700, const:0.0000, lowest:0.0000, co:0, bug:534
# Epoch: 1860000, loss:-0.0000352, const:0.0000, lowest:0.0000, co:0, bug:538
# Epoch: 1870000, loss:0.0001045, const:0.0000, lowest:0.0000, co:0, bug:543
# Epoch: 1880000, loss:0.0001083, const:0.0000, lowest:0.0000, co:0, bug:546
# Epoch: 1890000, loss:0.0000890, const:0.0000, lowest:0.0000, co:0, bug:551
# Epoch: 1900000, loss:0.0001155, const:0.0000, lowest:0.0000, co:0, bug:552
# Epoch: 1910000, loss:0.0000303, const:0.0000, lowest:0.0000, co:0, bug:554
# Epoch: 1920000, loss:0.0000988, const:0.0000, lowest:0.0000, co:0, bug:559
# Epoch: 1930000, loss:0.0000181, const:0.0000, lowest:0.0000, co:0, bug:565
# Epoch: 1940000, loss:0.0000067, const:0.0000, lowest:0.0000, co:0, bug:568
# Epoch: 1950000, loss:-0.0000746, const:0.0000, lowest:0.0000, co:0, bug:574
# Epoch: 1960000, loss:-0.0000913, const:0.0000, lowest:0.0000, co:0, bug:578
# Epoch: 1970000, loss:-0.0000544, const:0.0000, lowest:0.0000, co:0, bug:578
# Epoch: 1980000, loss:-0.0000546, const:0.0000, lowest:0.0000, co:0, bug:583
# Epoch: 1990000, loss:0.0000004, const:0.0000, lowest:0.0000, co:0, bug:587
